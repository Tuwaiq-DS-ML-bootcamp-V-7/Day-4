# %% [markdown]
# # Python_Lab_2.2

# %% [markdown]
# ### Task 1
# 1. Write a program that prompts the user to enter two numbers and prints their division. Handle cases where the user enters non-numeric values or attempts to divide by zero using a try-except block.

# %%
while True:
    try:
        # Prompt the user to enter two numbers
        num1 = float(input("Enter the first number: "))
        num2 = float(input("Enter the second number: "))

        # Perform division and handle division by zero
        result = num1 / num2
        print(f"The division result of {num1} by {num2} is: {result}")
        break  # Exit the loop if division is successful

    except ValueError:
        print("Error: Please enter numeric values.")
    except ZeroDivisionError:
        print("Error: Division by zero is not allowed.")
# Out:
# Enter the first number: 33
# Enter the second number: 22
# The division result of 33.0 by 22.0 is: 1.5

# %% [markdown]
# ### Task 2
# - Use "Random" library to do the following:
#     1. Create a list of random numbers using list comprehension.
#     2. Create a list of squares of the even numbers from random numbers using list comprehension.
#     3. Create a list of tuples (number, square) for random numbers using list comprehension.

# %%
import random

# Step 1: Create a list of random numbers using list comprehension
random_numbers = [random.randint(1, 100) for _ in range(10)]
print("Random numbers:", random_numbers)

# Step 2: Create a list of squares of the even numbers from random numbers using list comprehension
squares_of_evens = [x**2 for x in random_numbers if x % 2 == 0]
print("Squares of even numbers:", squares_of_evens)

# Step 3: Create a list of tuples (number, square) for random numbers using list comprehension
number_square_tuples = [(x, x**2) for x in random_numbers]
print("Number square tuples:", number_square_tuples)
# Out:
# Random numbers: [74, 11, 59, 12, 52, 10, 58, 78, 87, 76]
# Squares of even numbers: [5476, 144, 2704, 100, 3364, 6084, 5776]
# Number square tuples: [(74, 5476), (11, 121), (59, 3481), (12, 144), (52, 2704), (10, 100), (58, 3364), (78, 6084), (87, 7569), (76, 5776)]

# %% [markdown]
# ### Task 3
# - Create a dictionary where the keys are numbers from 1 to 5 and the values are list of their squares and cubes.
#
#   - **hint**: use dictionary of list comprehension.
#
# - Create a dictionary from two lists (one with keys and one with values) using dictionary comprehension.

# %%
# Using dictionary comprehension to create a dictionary of cubes
cubes_dict = {num: [num**3,num**2] for num in range(1, 6)}

# Print the resulting dictionary
print("Dictionary of cubes:")
print(cubes_dict)
# Out:
# Dictionary of cubes:
# {1: [1, 1], 2: [8, 4], 3: [27, 9], 4: [64, 16], 5: [125, 25]}

# %%
# Sample lists for keys and values
keys_list = ["A", "B", "C", "D", "E"]
values_list = [1, 2, 3, 4, 5]

# Using dictionary comprehension to create a dictionary from lists
dict_from_lists = {keys_list[i]: values_list[i] for i in range(len(keys_list))}

# Print the resulting dictionary
print("Dictionary from lists:")
print(dict_from_lists)
# Out:
# Dictionary from lists:
# {'A': 1, 'B': 2, 'C': 3, 'D': 4, 'E': 5}

# %% [markdown]
# ### Task 4
# - Given a dictionary where keys are student names and values are lists of their scores, write a function that updates the scores of students who have achieved a perfect score (100) by adding a bonus of 5 points to each score. Use dictionary comprehension to achieve this.
#
#     - Implement the function add_bonus_to_perfect_scores(student_scores) that adds a bonus of 5 points to each score of students who have achieved a perfect score (100).

# %%
def add_bonus_to_perfect_scores(student_scores):
    # Using dictionary comprehension to add bonus to perfect scores
    updated_scores = {name: [score + 5 if score == 100 else score for score in scores]
                      for name, scores in student_scores.items()}
    return updated_scores

# Sample dictionary
student_scores = {
    "Alice": [95, 100, 98],
    "Bob": [90, 100, 92],
    "Charlie": [100, 100, 100]
}

# Adding bonus to perfect scores
updated_scores = add_bonus_to_perfect_scores(student_scores)

# Display the updated scores
for name, scores in updated_scores.items():
    print(f"{name}: {scores}")
# Out:
# Alice: [95, 105, 98]
# Bob: [90, 105, 92]
# Charlie: [105, 105, 105]
