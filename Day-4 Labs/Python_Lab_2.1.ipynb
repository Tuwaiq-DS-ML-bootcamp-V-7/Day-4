# %% [markdown]
# # Python_Lab_2.1

# %% [markdown]
# ### Task 1
# 1. Write a function named is_prime that takes a number as a parameter and returns True if the number is prime and False otherwise. Print whether the number 29 is prime.

# %%
# write your code here ^_^

def isPrime(num):
    if num < 2:
        return False
    for i in range(2, int(num/2)+1):
        if num % i == 0:
         return False
    return True


if isPrime(29):
    print(f'the number is prime')
else:
    print(f'the number is not prime')
# Out:
# the number is prime

# %% [markdown]
# ### Task 2
# 1. Create a list of 10 numbers and sort them in descending order using the sort() function.
# 2. Use the len() function to print the length of the sorted list.
# 3. Use the zip() function to combine three lists (names, ages, and cities) into a list of tuples.
# 4. Use the range() function to create a list of even numbers from 2 to 20 and print the list.

# %%
# write your code here ^_^
nums = [2,4,5,6,44,6,77,8,44,33]
nums.sort(reverse=True)
names = ["osama", "ali", "ahmed"]
ages = [23, 23, 23]
city = ["Medina", "riyadh", "Jeddah"]
rangelst = []

for i in range(2, 20):
    if i % 2 == 0:
        rangelst.append(i)  



infoList = list(zip(names, ages, city))

print(nums)
print(len(nums))
print(infoList)
print(rangelst)
# Out:
# [77, 44, 44, 33, 8, 6, 6, 5, 4, 2]
# 10
# [('osama', 23, 'Medina'), ('ali', 23, 'riyadh'), ('ahmed', 23, 'Jeddah')]
# [2, 4, 6, 8, 10, 12, 14, 16, 18]

# %% [markdown]
# ### Task 3
# Build a phone book program that receives the phone number, and returns the name of the owner.
# You can follow the table below:
#
# | Name     | Number     |
# | -------- | ---------- |
# | Amal     | 1111111111 |
# | Mohammed | 2222222222 |
# | Khadijah | 3333333333 |
# | Abdullah | 4444444444 |
# | Rawan    | 5555555555 |
# | Faisal   | 6666666666 |
# | Layla    | 7777777777 |
#
# - If the number exists, print the owner. Otherwise, print "Sorry, the number is not found".
# - If the number is less or more than 10 numbers, print "This is invalid number".
# - If the number contains letters or symbols, print "This is invalid number".

# %%
# write your code here ^_^

contacts = {
    "Amal"    : 1111111111,
    "Mohammed": 2222222222,
    "Khadijah": 3333333333,
    "Abdullah": 4444444444,
    "Rawan"   : 5555555555,
    "Faisal"  : 6666666666,
    "Layla"   : 7777777777
}
def checkNumber(phoneNumber):
    try:
        phoneNumber = int(phoneNumber)
    except ValueError:
        return "This is invalid number"
    
    numlen = len(str(phoneNumber))
    if numlen > 10 or numlen < 10:
        return "This is invalid number"
    else:
        for name, num in contacts.items():
            if phoneNumber == num:
                return name
    
    return "Sorry, the number is not found"

print(checkNumber(1111111111))
# Out:
# Amal

# %% [markdown]
# ### Task 4
# - Given the following list : [5, 4, 17, 19, 30, 2, 7, 10, 45]
#     1. Use a lambda function to filter out only the odd numbers.
#     2. Print the new list of odd numbers.

# %%
# write your code here ^_^
l = [5, 4, 17, 19, 30, 2, 7, 10, 45]

odd = lambda i : i % 2 != 0

oddlist = [i for i in l if odd(i) == True]
print(oddlist)
# Out:
# [5, 17, 19, 7, 45]
